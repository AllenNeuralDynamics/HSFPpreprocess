# %%
from skimage import io

temp = io.imread('C:\AIND\output_data\Tiffs_2024-08-12T13_43_08.6638592-07_00\Tiffs_5.tif')

# Read tiff file

# %%
from PIL import Image
import numpy as np

tiff = Image.open('C:\AIND\output_data\Tiffs_2024-08-12T13_43_08.6638592-07_00\Tiffs_0.tif')

image_sequence = []
while True:
    try:
        image_sequence.append(np.array(tiff))
        tiff.seek(tiff.tell() + 1)
    except EOFError:
        break

# %%
print(f'Shape of the image: {image_sequence[2].shape}')

# Display the image
import matplotlib.pyplot as plt
plt.imshow(image_sequence[999])
plt.show()
# Out:
# Shape of the image: (2048, 2048)
